# %%
from src.loaders.data_loader import load_train_data


train_df = load_train_data()

# %%
train_df["Day"] = train_df["Day"] % 365
train_df
# Out:
#        Day  Hour  Minute  DHI  DNI   WS     RH   T  TARGET
# 0        0     0       0    0    0  1.5  69.08 -12     0.0
# 1        0     0      30    0    0  1.5  69.06 -12     0.0
# 2        0     1       0    0    0  1.6  71.78 -12     0.0
# 3        0     1      30    0    0  1.6  71.75 -12     0.0
# 4        0     2       0    0    0  1.6  75.20 -12     0.0
# ...    ...   ...     ...  ...  ...  ...    ...  ..     ...
# 52555  364    21      30    0    0  2.4  70.70  -4     0.0
# 52556  364    22       0    0    0  2.4  66.79  -4     0.0
# 52557  364    22      30    0    0  2.2  66.78  -4     0.0
# 52558  364    23       0    0    0  2.1  67.72  -4     0.0
# 52559  364    23      30    0    0  2.1  67.70  -4     0.0
#
# [52560 rows x 9 columns]

# %%
train_df.groupby("Day").std()["TARGET"].median()
# Out:
# 24.150293648408073

# %%
import matplotlib.pyplot as plt

plt.subplot(211)
train_df.groupby("Day").std()["TARGET"].plot()
plt.subplot(212)
train_df.groupby("Day").mean()["TARGET"].plot()
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
plt.subplot(221)
train_df.groupby("Hour").std()["TARGET"].plot()
plt.subplot(222)
train_df.groupby(["Hour", "Minute"]).std()["TARGET"].plot()

plt.subplot(223)
train_df.groupby("Hour").mean()["TARGET"].plot()
plt.subplot(224)
train_df.groupby(["Hour", "Minute"]).mean()["TARGET"].plot()
# Out:
# <AxesSubplot:xlabel='Hour,Minute'>

# %%
import matplotlib.pyplot as plt

print("1월")

month=0
for i in range(7):
    plt.figure(figsize=(16, 2))
    plt.subplot(1, 4, 1)
    train_df[train_df["Day"] == month * 30 + i * 4 + 0].reset_index()["TARGET"].plot()
    plt.subplot(1, 4, 2)
    train_df[train_df["Day"] == month * 30 + i * 4 + 1].reset_index()["TARGET"].plot()
    plt.subplot(1, 4, 3)
    train_df[train_df["Day"] == month * 30 + i * 4 + 2].reset_index()["TARGET"].plot()
    plt.subplot(1, 4, 4)
    train_df[train_df["Day"] == month * 30 + i * 4 + 3].reset_index()["TARGET"].plot()
    plt.show()
# Out:
# 1월

# %%
import matplotlib.pyplot as plt

for i in range(12):
    plt.figure(figsize=(16, 2))
    plt.subplot(1, 3, 1)
    train_df[train_df["Day"] == i * 30 + 0].reset_index()["T"].plot()
    plt.subplot(1, 3, 2)
    train_df[train_df["Day"] == i * 30 + 1].reset_index()["T"].plot()
    plt.subplot(1, 3, 3)
    train_df[train_df["Day"] == i * 30 + 2].reset_index()["T"].plot()
    plt.show()

# %%
specific_time_15 = train_df.query('Hour == 15').query('Minute == 0')

specific_time_16 = train_df.query('Hour == 16').query('Minute == 0')

specific_time_17 = train_df.query('Hour == 17').query('Minute == 0')
specific_time_18 = train_df.query('Hour == 18').query('Minute == 0')
specific_time
# Out:
#        Day  Hour  Minute  DHI  DNI   WS     RH   T  TARGET
# 36       0    18       0    0    0  2.1  76.43  -8     0.0
# 37       0    18      30    0    0  2.2  76.44  -8     0.0
# 84       1    18       0    0    0  1.3  73.62  -6     0.0
# 85       1    18      30    0    0  1.5  73.60  -6     0.0
# 132      2    18       0    0    0  2.0  85.23 -10     0.0
# ...    ...   ...     ...  ...  ...  ...    ...  ..     ...
# 52453  362    18      30    0    0  1.4  50.32   0     0.0
# 52500  363    18       0    0    0  4.1  49.07   1     0.0
# 52501  363    18      30    0    0  3.4  49.10   0     0.0
# 52548  364    18       0    0    0  0.8  70.99  -3     0.0
# 52549  364    18      30    0    0  0.9  70.99  -3     0.0
#
# [2190 rows x 9 columns]

# %%
i = 700
s = slice(i, i + 100)
specific_time_15.reset_index()["TARGET"][s].plot()
specific_time_16.reset_index()["TARGET"][s].plot()
specific_time_17.reset_index()["TARGET"][s].plot()
specific_time_18.reset_index()["TARGET"][s].plot()
# Out:
# <AxesSubplot:>

# %%
i = 15
s = slice(i, i + 7)
specific_time_15.reset_index()["TARGET"][s].plot()
specific_time_16.reset_index()["TARGET"][s].plot()
specific_time_17.reset_index()["TARGET"][s].plot()
specific_time_18.reset_index()["TARGET"][s].plot()
# Out:
# <AxesSubplot:>
